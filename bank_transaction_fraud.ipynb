# %% [markdown]
# <a href="https://colab.research.google.com/github/toshilk90/resume-html/blob/main/bank_transaction_fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing liberaries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#importing Data
dataset = pd.read_csv("Bank_Transaction.csv")

# %%
dataset
# Out:
#                                  Customer_ID        Customer_Name  Gender  \
# 0       d5f6ec07-d69e-4f47-b9b4-7c58ff17c19e           Osha Tella    Male
# 1       7c14ad51-781a-4db9-b7bd-67439c175262      Hredhaan Khosla  Female
# 2       3a73a0e5-d4da-45aa-85f3-528413900a35       Ekani Nazareth    Male
# 3       7902f4ef-9050-4a79-857d-9c2ea3181940  Yamini Ramachandran  Female
# 4       3a4bba70-d9a9-4c5f-8b92-1735fd8c19e9         Kritika Rege  Female
# ...                                      ...                  ...     ...
# 199995  b8bdae19-296f-48b7-9104-e055d33a09ac        Vedhika Magar  Female
# 199996  635bc099-8a93-48ee-829a-bf2283fe8fda            Aashi Pai    Male
# 199997  c1b31cc2-0905-47e8-8cc5-6461d1f3ba33          Dayita Shan  Female
# 199998  32bb8e66-f3fa-43bf-8242-dab9a6116310          Unnati Vyas  Female
# 199999  f3dd92ef-b17a-45d2-b6cb-fdbee20843fe           Gopal Rout    Male
#
#         Age                                     State                City  \
# ...

# %%
dataset.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Gender', 'Age', 'State', 'City',
#        'Bank_Branch', 'Account_Type', 'Transaction_ID', 'Transaction_Date',
#        'Transaction_Time', 'Transaction_Amount', 'Merchant_ID',
#        'Transaction_Type', 'Merchant_Category', 'Account_Balance',
#        'Transaction_Device', 'Transaction_Location', 'Device_Type', 'Is_Fraud',
#        'Transaction_Currency', 'Customer_Contact', 'Transaction_Description',
#        'Customer_Email'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Customer_ID              200000 non-null  object
#  1   Customer_Name            200000 non-null  object
#  2   Gender                   200000 non-null  object
#  3   Age                      200000 non-null  int64
#  4   State                    200000 non-null  object
#  5   City                     200000 non-null  object
#  6   Bank_Branch              200000 non-null  object
#  7   Account_Type             200000 non-null  object
#  8   Transaction_ID           200000 non-null  object
#  9   Transaction_Date         200000 non-null  object
#  10  Transaction_Time         200000 non-null  object
#  11  Transaction_Amount       200000 non-null  float64
#  12  Merchant_ID              200000 non-null  object
# ...

# %%
dataset.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Gender', 'Age', 'State', 'City',
#        'Bank_Branch', 'Account_Type', 'Transaction_ID', 'Transaction_Date',
#        'Transaction_Time', 'Transaction_Amount', 'Merchant_ID',
#        'Transaction_Type', 'Merchant_Category', 'Account_Balance',
#        'Transaction_Device', 'Transaction_Location', 'Device_Type', 'Is_Fraud',
#        'Transaction_Currency', 'Customer_Contact', 'Transaction_Description',
#        'Customer_Email'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (200000, 24)

# %%
dataset.size
# Out:
# 4800000

# %%
dataset.dtypes
# Out:
# Customer_ID                 object
# Customer_Name               object
# Gender                      object
# Age                          int64
# State                       object
# City                        object
# Bank_Branch                 object
# Account_Type                object
# Transaction_ID              object
# Transaction_Date            object
# Transaction_Time            object
# Transaction_Amount         float64
# Merchant_ID                 object
# Transaction_Type            object
# Merchant_Category           object
# Account_Balance            float64
# Transaction_Device          object
# Transaction_Location        object
# Device_Type                 object
# Is_Fraud                     int64
# Transaction_Currency        object
# Customer_Contact            object
# Transaction_Description     object
# Customer_Email              object
# dtype: object

# %%
dataset.describe()
# Out:
#                  Age  Transaction_Amount  Account_Balance       Is_Fraud
# count  200000.000000       200000.000000    200000.000000  200000.000000
# mean       44.015110        49538.015554     52437.988784       0.050440
# std        15.288774        28551.874004     27399.507128       0.218852
# min        18.000000           10.290000      5000.820000       0.000000
# 25%        31.000000        24851.345000     28742.395000       0.000000
# 50%        44.000000        49502.440000     52372.555000       0.000000
# 75%        57.000000        74314.625000     76147.670000       0.000000
# max        70.000000        98999.980000     99999.950000       1.000000

# %%
dataset.describe(include=["object"])
# Out:
#                                  Customer_ID Customer_Name  Gender     State  \
# count                                 200000        200000  200000    200000
# unique                                200000        142699       2        34
# top     d5f6ec07-d69e-4f47-b9b4-7c58ff17c19e   Aahana Kala    Male  Nagaland
# freq                                       1             8  100452      6031
#
#               City        Bank_Branch Account_Type  \
# count       200000             200000       200000
# unique         145                145            3
# top     Chandigarh  Chandigarh Branch     Checking
# freq          8135               8135        66924
#
#                               Transaction_ID Transaction_Date  \
# count                                 200000           200000
# unique                                200000               31
# top     4fa3208f-9e23-42dc-b330-844829d0c12c       29-01-2025
# freq                                       1             6854
#
# ...

# %%
dataset.describe(include="all")
# Out:
#                                  Customer_ID Customer_Name  Gender  \
# count                                 200000        200000  200000
# unique                                200000        142699       2
# top     d5f6ec07-d69e-4f47-b9b4-7c58ff17c19e   Aahana Kala    Male
# freq                                       1             8  100452
# mean                                     NaN           NaN     NaN
# std                                      NaN           NaN     NaN
# min                                      NaN           NaN     NaN
# 25%                                      NaN           NaN     NaN
# 50%                                      NaN           NaN     NaN
# 75%                                      NaN           NaN     NaN
# max                                      NaN           NaN     NaN
#
#                   Age     State        City        Bank_Branch Account_Type  \
# count   200000.000000    200000      200000             200000       200000
# ...

# %%
print("Customer_Name :", dataset["Customer_Name"].duplicated())
print("*****************************")
# Out:
# Customer_Name : 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 199995     True
# 199996     True
# 199997    False
# 199998     True
# 199999    False
# Name: Customer_Name, Length: 200000, dtype: bool
# *****************************

# %%
print("Customer_Name :")
print(dataset["Customer_Name"].value_counts())
print("*****************************")

print("Gender :")
print(dataset["Gender"].value_counts())
print("*****************************")

print("State :")
print(dataset["State"].value_counts())
print("*****************************")

print("Bank_Branch :")
print(dataset["Bank_Branch"].value_counts())
print("*****************************")

print("Transaction_Date :")
print(dataset["Transaction_Date"].value_counts())
print("*****************************")

print("Transaction_Amount :", dataset["Transaction_Amount"].value_counts())
print("*****************************")

print("Transaction_Type :", dataset["Transaction_Type"].value_counts())
print("*****************************")

print("Merchant_Category:")
print(dataset["Merchant_Category"].value_counts())
print("*****************************")

print("FLAGGED_FRAUD:")
print(dataset["Is_Fraud"].value_counts())
print("*****************************")
# Out:
# Customer_Name :
# Customer_Name
# Aahana Kala        8
# Krishna Sani       7
# Madhav Kala        7
# Jonathan Dara      7
# Mitali Lad         7
#                   ..
# Chaitaly Parekh    1
# Omkaar Gandhi      1
# Oviya Chokshi      1
# Theodore Hari      1
# Gopal Rout         1
# Name: count, Length: 142699, dtype: int64
# *****************************
# Gender :
# Gender
# Male      100452
# Female     99548
# Name: count, dtype: int64
# *****************************
# State :
# State
# Nagaland                                    6031
# Meghalaya                                   6003
# Uttar Pradesh                               6002
# Uttarakhand                                 5985
# Lakshadweep                                 5954
# Telangana                                   5952
# Haryana                                     5947
# Delhi                                       5943
# Kerala                                      5933
# ...

# %%
sns.countplot(data=dataset, x='Bank_Branch')
# Out:
# <Axes: xlabel='Bank_Branch', ylabel='count'>

# %%
sns.countplot(data=dataset, x='Is_Fraud')
# Out:
# <Axes: xlabel='Is_Fraud', ylabel='count'>

# %%
dataset.isna()
# Out:
#         Customer_ID  Customer_Name  Gender    Age  State   City  Bank_Branch  \
# 0             False          False   False  False  False  False        False
# 1             False          False   False  False  False  False        False
# 2             False          False   False  False  False  False        False
# 3             False          False   False  False  False  False        False
# 4             False          False   False  False  False  False        False
# ...             ...            ...     ...    ...    ...    ...          ...
# 199995        False          False   False  False  False  False        False
# 199996        False          False   False  False  False  False        False
# 199997        False          False   False  False  False  False        False
# 199998        False          False   False  False  False  False        False
# 199999        False          False   False  False  False  False        False
#
# ...

# %%
dataset.isna().sum().sort_values(ascending = False)
# Out:
# Customer_ID                0
# Customer_Name              0
# Transaction_Description    0
# Customer_Contact           0
# Transaction_Currency       0
# Is_Fraud                   0
# Device_Type                0
# Transaction_Location       0
# Transaction_Device         0
# Account_Balance            0
# Merchant_Category          0
# Transaction_Type           0
# Merchant_ID                0
# Transaction_Amount         0
# Transaction_Time           0
# Transaction_Date           0
# Transaction_ID             0
# Account_Type               0
# Bank_Branch                0
# City                       0
# State                      0
# Age                        0
# Gender                     0
# Customer_Email             0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dataset.isnull(), cmap="viridis", cbar=False)
plt.title("Null Values Heatmap")
plt.show()

# %%
dataset.duplicated().value_counts()

#(dataset["type"].duplicated().sum()/len(dataset["type"])*100)
# Out:
# False    200000
# Name: count, dtype: int64

# %%
(dataset["Is_Fraud"].value_counts())
# Out:
# Is_Fraud
# 0    189912
# 1     10088
# Name: count, dtype: int64

# %%
dataset
# Out:
#                                  Customer_ID        Customer_Name  Gender  \
# 0       d5f6ec07-d69e-4f47-b9b4-7c58ff17c19e           Osha Tella    Male
# 1       7c14ad51-781a-4db9-b7bd-67439c175262      Hredhaan Khosla  Female
# 2       3a73a0e5-d4da-45aa-85f3-528413900a35       Ekani Nazareth    Male
# 3       7902f4ef-9050-4a79-857d-9c2ea3181940  Yamini Ramachandran  Female
# 4       3a4bba70-d9a9-4c5f-8b92-1735fd8c19e9         Kritika Rege  Female
# ...                                      ...                  ...     ...
# 199995  b8bdae19-296f-48b7-9104-e055d33a09ac        Vedhika Magar  Female
# 199996  635bc099-8a93-48ee-829a-bf2283fe8fda            Aashi Pai    Male
# 199997  c1b31cc2-0905-47e8-8cc5-6461d1f3ba33          Dayita Shan  Female
# 199998  32bb8e66-f3fa-43bf-8242-dab9a6116310          Unnati Vyas  Female
# 199999  f3dd92ef-b17a-45d2-b6cb-fdbee20843fe           Gopal Rout    Male
#
#         Age                                     State                City  \
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=dataset, palette='Set3')
plt.title('Boxplot for Outliers Detection - in All Columns')
plt.xticks(rotation=90)
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Customer_ID              200000 non-null  object
#  1   Customer_Name            200000 non-null  object
#  2   Gender                   200000 non-null  object
#  3   Age                      200000 non-null  int64
#  4   State                    200000 non-null  object
#  5   City                     200000 non-null  object
#  6   Bank_Branch              200000 non-null  object
#  7   Account_Type             200000 non-null  object
#  8   Transaction_ID           200000 non-null  object
#  9   Transaction_Date         200000 non-null  object
#  10  Transaction_Time         200000 non-null  object
#  11  Transaction_Amount       200000 non-null  float64
#  12  Merchant_ID              200000 non-null  object
# ...

# %%
dataset.head(1500)
# Out:
#                                Customer_ID        Customer_Name  Gender  Age  \
# 0     d5f6ec07-d69e-4f47-b9b4-7c58ff17c19e           Osha Tella    Male   60
# 1     7c14ad51-781a-4db9-b7bd-67439c175262      Hredhaan Khosla  Female   51
# 2     3a73a0e5-d4da-45aa-85f3-528413900a35       Ekani Nazareth    Male   20
# 3     7902f4ef-9050-4a79-857d-9c2ea3181940  Yamini Ramachandran  Female   57
# 4     3a4bba70-d9a9-4c5f-8b92-1735fd8c19e9         Kritika Rege  Female   43
# ...                                    ...                  ...     ...  ...
# 1495  b0378ab8-5c02-451c-9c88-fa60ad3e411c       Shravya Mander  Female   44
# 1496  ff320754-ce86-41bf-8e77-1cfab2ff8fb2    Chaitaly Aggarwal    Male   66
# 1497  07a49040-eb5a-4f49-8edd-ac46caa5bda3           Lekha Keer    Male   58
# 1498  59f28278-cd1a-4a6f-8704-e64608a608ff         Girish Kakar  Female   64
# 1499  23b3a60c-95b7-479e-87e7-b6ee3749ae08       Kashvi Narayan    Male   20
#
# ...

# %%
dataset.tail(3789)
# Out:
#                                  Customer_ID        Customer_Name  Gender  \
# 196211  49cb573d-e991-4457-b25e-96286f7bbacd           Robert Ram  Female
# 196212  f8593227-7c59-40c7-bc55-7b908af4d816  Bachittar Ahluwalia  Female
# 196213  07a868b8-2c98-4928-9f27-2b8d877d4f8c          Sanaya Peri    Male
# 196214  91cd14b0-2aab-492f-9fdc-76ccd3d181c7         Daniel Ratti  Female
# 196215  075f9202-98a7-480d-88f6-0b9fc2a1b310          Dipta Sidhu    Male
# ...                                      ...                  ...     ...
# 199995  b8bdae19-296f-48b7-9104-e055d33a09ac        Vedhika Magar  Female
# 199996  635bc099-8a93-48ee-829a-bf2283fe8fda            Aashi Pai    Male
# 199997  c1b31cc2-0905-47e8-8cc5-6461d1f3ba33          Dayita Shan  Female
# 199998  32bb8e66-f3fa-43bf-8242-dab9a6116310          Unnati Vyas  Female
# 199999  f3dd92ef-b17a-45d2-b6cb-fdbee20843fe           Gopal Rout    Male
#
#         Age                                     State         City  \
# ...

# %%
# Select only numerical features for correlation calculation
numerical_features = dataset.select_dtypes(include=np.number)

# Calculate the correlation matrix
corr_matrix = numerical_features.corr()

# Display the correlation matrix
corr_matrix
# Out:
#                          Age  Transaction_Amount  Account_Balance  Is_Fraud
# Age                 1.000000           -0.003087         0.000269 -0.001517
# Transaction_Amount -0.003087            1.000000        -0.001735 -0.002100
# Account_Balance     0.000269           -0.001735         1.000000  0.000125
# Is_Fraud           -0.001517           -0.002100         0.000125  1.000000

# %%
corr_matrix["Is_Fraud"].sort_values(ascending=False)
# Out:
# Is_Fraud              1.000000
# Account_Balance       0.000125
# Age                  -0.001517
# Transaction_Amount   -0.002100
# Name: Is_Fraud, dtype: float64

# %%
plt.figure(figsize=(30, 15))
# Select only numerical features for correlation calculation
numerical_features = dataset.select_dtypes(include=np.number)

# Calculate the correlation matrix for numerical features only
corr_matrix = numerical_features.corr()

# Plot the heatmap using the correlation matrix of numerical features
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap="coolwarm")
plt.title("Correlation Plot")
plt.show()

# %%
dataset.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Gender', 'Age', 'State', 'City',
#        'Bank_Branch', 'Account_Type', 'Transaction_ID', 'Transaction_Date',
#        'Transaction_Time', 'Transaction_Amount', 'Merchant_ID',
#        'Transaction_Type', 'Merchant_Category', 'Account_Balance',
#        'Transaction_Device', 'Transaction_Location', 'Device_Type', 'Is_Fraud',
#        'Transaction_Currency', 'Customer_Contact', 'Transaction_Description',
#        'Customer_Email'],
#       dtype='object')

# %%
#creating independent and dependent variables X & y

X = dataset.drop(["Customer_Name", "Bank_Branch", "Is_Fraud"], axis=1)
y = dataset["Is_Fraud"] #dependent variable / target variable

# %%
X.head()
# Out:
#                             Customer_ID  Gender  Age        State  \
# 0  d5f6ec07-d69e-4f47-b9b4-7c58ff17c19e    Male   60       Kerala
# 1  7c14ad51-781a-4db9-b7bd-67439c175262  Female   51  Maharashtra
# 2  3a73a0e5-d4da-45aa-85f3-528413900a35    Male   20        Bihar
# 3  7902f4ef-9050-4a79-857d-9c2ea3181940  Female   57   Tamil Nadu
# 4  3a4bba70-d9a9-4c5f-8b92-1735fd8c19e9  Female   43       Punjab
#
#                  City Account_Type                        Transaction_ID  \
# 0  Thiruvananthapuram      Savings  4fa3208f-9e23-42dc-b330-844829d0c12c
# 1              Nashik     Business  c9de0c06-2c4c-40a9-97ed-3c7b8f97c79c
# 2           Bhagalpur      Savings  e41c55f9-c016-4ff3-872b-cae72467c75c
# 3             Chennai     Business  7f7ee11b-ff2c-45a3-802a-49bc47c02ecb
# 4            Amritsar      Savings  f8e6ac6f-81a1-4985-bf12-f60967d852ef
#
#   Transaction_Date Transaction_Time  Transaction_Amount  ... Transaction_Type  \
# ...

# %%
X.tail()
# Out:
#                                  Customer_ID  Gender  Age  \
# 199995  b8bdae19-296f-48b7-9104-e055d33a09ac  Female   55
# 199996  635bc099-8a93-48ee-829a-bf2283fe8fda    Male   51
# 199997  c1b31cc2-0905-47e8-8cc5-6461d1f3ba33  Female   41
# 199998  32bb8e66-f3fa-43bf-8242-dab9a6116310  Female   28
# 199999  f3dd92ef-b17a-45d2-b6cb-fdbee20843fe    Male   34
#
#                                            State        City Account_Type  \
# 199995  Dadra and Nagar Haveli and Daman and Diu         Diu     Business
# 199996                                   Manipur   Kangpokpi     Business
# 199997                                Chandigarh  Chandigarh      Savings
# 199998                                 Telangana   Nizamabad     Checking
# 199999                                  Nagaland      Kohima     Business
#
#                               Transaction_ID Transaction_Date  \
# 199995  8d856bc7-4666-4509-a067-48d67500694a       08-01-2025
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Is_Fraud, dtype: int64

# %%
y.tail()
# Out:
# 199995    0
# 199996    0
# 199997    0
# 199998    0
# 199999    0
# Name: Is_Fraud, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into test and train for calculating accuracy
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=39)

# %%
X_train.shape
# Out:
# (140000, 21)

# %%
X_test.shape
# Out:
# (60000, 21)

# %%
y_train.shape
# Out:
# (140000,)

# %%
y_test.shape
# Out:
# (60000,)

# %%
X_train
# Out:
#         Gender  Age                                     State           City  \
# 1735    Female   18                                 Karnataka          Hubli
# 178216    Male   18  Dadra and Nagar Haveli and Daman and Diu       Silvassa
# 173890    Male   19                                     Delhi     West Delhi
# 175463    Male   22                                    Kerala       Kottayam
# 93894     Male   35                              Chhattisgarh         Raipur
# ...        ...  ...                                       ...            ...
# 174307  Female   44                                Chandigarh     Chandigarh
# 31302   Female   55                                     Assam      Dibrugarh
# 121748  Female   35                                   Manipur  Churachandpur
# 164928  Female   55                                    Kerala        Trichur
# 60809     Male   36                             Uttar Pradesh         Meerut
#
# ...

# %%
X_test
# Out:
#         Gender  Age           State        City Account_Type  \
# 139746    Male   28  Andhra Pradesh     Nellore      Savings
# 11856     Male   43       Rajasthan     Udaipur     Business
# 169151  Female   37           Assam   Dibrugarh      Savings
# 61514   Female   26  Andhra Pradesh      Guntur     Checking
# 102762    Male   62     West Bengal    Siliguri     Business
# ...        ...  ...             ...         ...          ...
# 29986   Female   38       Rajasthan     Udaipur      Savings
# 107742    Male   33   Uttar Pradesh    Varanasi      Savings
# 198265    Male   31       Karnataka       Hubli     Checking
# 453       Male   18     Uttarakhand    Nainital     Business
# 134766    Male   30      Chandigarh  Chandigarh     Checking
#
#                               Transaction_ID Transaction_Date  \
# 139746  f8b88c99-c431-4563-b468-395266b55ee4       10-01-2025
# 11856   55ab4603-5627-450c-bf30-dbdfbe19c1d9       25-01-2025
# ...
